# %%
import urllib
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.sql import text
import numpy as np
import talib
from talib import abstract
from ta.utils import dropna
import numpy as np
import concurrent.futures


HOST = "DESKTOP-JJT739B\SQLEXPRESS"
DB = "nse"
DRIVER = "ODBC+Driver+11+for+SQL+Server"

NO_OF_WORKERS = 2
HISTORY_TABLE = "bse_history"
OUTPUT_TABLENAME = "bse_indicators"

column_mappings = {
    "date": "Date",
    "symbol": "Symbol",
    "open": "Open",
    "low": "Low",
    "high": "High",
    "close": "Close",
    "volume": "Volume",
    "series": "Series"
}

INCREMENTAL_CHECK_QUERY = "SELECT [{DATE_COLUMN_NAME}] FROM {HISTORY_TABLE_NAME} WHERE NOT EXISTS (SELECT 1 FROM {CALC_TABLE_NAME} WHERE\
                        {HISTORY_TABLE_NAME}.{DATE_COLUMN_NAME} = {CALC_TABLE_NAME}.{DATE_COLUMN_NAME} AND {HISTORY_TABLE_NAME}.{SYMBOL_COLUMN_NAME} = \
                        {CALC_TABLE_NAME}.{SYMBOL_COLUMN_NAME}) and {SYMBOL_COLUMN_NAME}='{SYMBOL_NAME}' order by [{DATE_COLUMN_NAME}] DESC"

GET_PREVIOUS_DAYS_QUERY = "select top({NO_OF_ROWS}) * from {HISTORY_TABLE_NAME} where {SYMBOL_COLUMN_NAME}='{SYMBOL_NAME}' order by [{DATE_COLUMN_NAME}] desc"


CREATE_OUTPUT_TABLE_QUERY = f"""
IF NOT EXISTS (SELECT * FROM sysobjects WHERE name='{OUTPUT_TABLENAME}' and xtype='U')
CREATE TABLE {OUTPUT_TABLENAME} (
	[ID] [bigint] PRIMARY KEY IDENTITY(1,1),
	[Date] [date] NOT NULL,
	[Symbol] [varchar](250) NOT NULL,
	[Series] [varchar](20) NULL,
	[Prev Close] [float](2) NULL,
	[open] [float](2) NOT NULL,
	[high] [float](2) NOT NULL,
	[low] [float](2) NOT NULL,
	[Last] [float](2) NULL,
	[close] [float](2) NOT NULL,
	[VWAP] [float](2) NULL,
	[volume] [float](2) NOT NULL,
	[Turnover] [float] NULL,
	[Trades] [float](2) NULL,
	[Deliverable Volume] [float](2) NULL,
	[%Deliverble] [float](2) NULL,
	[Cycle_HT_DCPERIOD] [float](2) NULL,
	[Cycle_HT_DCPHASE] [float](2) NULL,
	[Cycle_HT_PHASOR_inphase] [float](2) NULL,
	[Cycle_HT_PHASOR_quadrature] [float](2) NULL,
	[Cycle_HT_SINE_sine] [float](2) NULL,
	[Cycle_HT_SINE_leadsine] [float](2) NULL,
	[Cycle_HT_TRENDMODE] [float](2) NULL,
	[Math_ADD] [float](2) NULL,
	[Math_DIV] [float](2) NULL,
	[Math_MAX] [float](2) NULL,
	[Math_MAXINDEX] [float](2) NULL,
	[Math_MIN] [float](2) NULL,
	[Math_MININDEX] [float](2) NULL,
	[Math_MINMAX_min] [float](2) NULL,
	[Math_MINMAX_max] [float](2) NULL,
	[Math_MINMAXINDEX_minidx] [float](2) NULL,
	[Math_MINMAXINDEX_maxidx] [float](2) NULL,
	[Math_MULT] [float](2) NULL,
	[Math_SUB] [float](2) NULL,
	[Math_SUM] [float](2) NULL,
	[Math_ATAN] [float](2) NULL,
	[Math_CEIL] [float](2) NULL,
	[Math_COS] [float](2) NULL,
	[Math_COSH] [float] NULL,
	[Math_EXP] [float] NULL,
	[Math_FLOOR] [float](2) NULL,
	[Math_LN] [float](2) NULL,
	[Math_LOG10] [float](2) NULL,
	[Math_SIN] [float](2) NULL,
	[Math_SINH] [float] NULL,
	[Math_SQRT] [float](2) NULL,
	[Math_TAN] [float](2) NULL,
	[Math_TANH] [float](2) NULL,
	[Momentum_ADX] [float](2) NULL,
	[Momentum_ADXR] [float](2) NULL,
	[Momentum_APO] [float](2) NULL,
	[Momentum_AROON_aroondown] [float](2) NULL,
	[Momentum_AROON_aroonup] [float](2) NULL,
	[Momentum_AROONOSC] [float](2) NULL,
	[Momentum_BOP] [float](2) NULL,
	[Momentum_CCI] [float](2) NULL,
	[Momentum_CMO] [float](2) NULL,
	[Momentum_DX] [float](2) NULL,
	[Momentum_MACD_macd] [float](2) NULL,
	[Momentum_MACD_macdsignal] [float](2) NULL,
	[Momentum_MACD_macdhist] [float](2) NULL,
	[Momentum_MACDEXT_macd] [float](2) NULL,
	[Momentum_MACDEXT_macdsignal] [float](2) NULL,
	[Momentum_MACDEXT_macdhist] [float](2) NULL,
	[Momentum_MACDFIX_macd] [float](2) NULL,
	[Momentum_MACDFIX_macdsignal] [float](2) NULL,
	[Momentum_MACDFIX_macdhist] [float](2) NULL,
	[Momentum_MFI] [float](2) NULL,
	[Momentum_MINUS_DI] [float](2) NULL,
	[Momentum_MINUS_DM] [float](2) NULL,
	[Momentum_MOM] [float](2) NULL,
	[Momentum_PLUS_DI] [float](2) NULL,
	[Momentum_PLUS_DM] [float](2) NULL,
	[Momentum_PPO] [float](2) NULL,
	[Momentum_ROC] [float](2) NULL,
	[Momentum_ROCP] [float](2) NULL,
	[Momentum_ROCR] [float](2) NULL,
	[Momentum_ROCR100] [float](2) NULL,
	[Momentum_RSI] [float](2) NULL,
	[Momentum_STOCH_slowk] [float](2) NULL,
	[Momentum_STOCH_slowd] [float](2) NULL,
	[Momentum_STOCHF_fastk] [float](2) NULL,
	[Momentum_STOCHF_fastd] [float](2) NULL,
	[Momentum_STOCHRSI_fastk] [float](2) NULL,
	[Momentum_STOCHRSI_fastd] [float](2) NULL,
	[Momentum_TRIX] [float](2) NULL,
	[Momentum_ULTOSC] [float](2) NULL,
	[Momentum_WILLR] [float](2) NULL,
	[Overlap_BBANDS_upperband] [float](2) NULL,
	[Overlap_BBANDS_middleband] [float](2) NULL,
	[Overlap_BBANDS_lowerband] [float](2) NULL,
	[Overlap_DEMA] [float](2) NULL,
	[Overlap_EMA] [float](2) NULL,
	[Overlap_HT_TRENDLINE] [float](2) NULL,
	[Overlap_KAMA] [float](2) NULL,
	[Overlap_MA] [float](2) NULL,
	[Overlap_MAMA_mama] [float](2) NULL,
	[Overlap_MAMA_fama] [float](2) NULL,
	[Overlap_MIDPOINT] [float](2) NULL,
	[Overlap_MIDPRICE] [float](2) NULL,
	[Overlap_SAR] [float](2) NULL,
	[Overlap_SAREXT] [float](2) NULL,
	[Overlap_SMA] [float](2) NULL,
	[Overlap_T3] [float](2) NULL,
	[Overlap_TEMA] [float](2) NULL,
	[Overlap_TRIMA] [float](2) NULL,
	[Overlap_WMA] [float](2) NULL,
	[Pattern_CDL2CROWS] [float](2) NULL,
	[Pattern_CDL3BLACKCROWS] [float](2) NULL,
	[Pattern_CDL3INSIDE] [float](2) NULL,
	[Pattern_CDL3LINESTRIKE] [float](2) NULL,
	[Pattern_CDL3OUTSIDE] [float](2) NULL,
	[Pattern_CDL3STARSINSOUTH] [float](2) NULL,
	[Pattern_CDL3WHITESOLDIERS] [float](2) NULL,
	[Pattern_CDLABANDONEDBABY] [float](2) NULL,
	[Pattern_CDLADVANCEBLOCK] [float](2) NULL,
	[Pattern_CDLBELTHOLD] [float](2) NULL,
	[Pattern_CDLBREAKAWAY] [float](2) NULL,
	[Pattern_CDLCLOSINGMARUBOZU] [float](2) NULL,
	[Pattern_CDLCONCEALBABYSWALL] [float](2) NULL,
	[Pattern_CDLCOUNTERATTACK] [float](2) NULL,
	[Pattern_CDLDARKCLOUDCOVER] [float](2) NULL,
	[Pattern_CDLDOJI] [float](2) NULL,
	[Pattern_CDLDOJISTAR] [float](2) NULL,
	[Pattern_CDLDRAGONFLYDOJI] [float](2) NULL,
	[Pattern_CDLENGULFING] [float](2) NULL,
	[Pattern_CDLEVENINGDOJISTAR] [float](2) NULL,
	[Pattern_CDLEVENINGSTAR] [float](2) NULL,
	[Pattern_CDLGAPSIDESIDEWHITE] [float](2) NULL,
	[Pattern_CDLGRAVESTONEDOJI] [float](2) NULL,
	[Pattern_CDLHAMMER] [float](2) NULL,
	[Pattern_CDLHANGINGMAN] [float](2) NULL,
	[Pattern_CDLHARAMI] [float](2) NULL,
	[Pattern_CDLHARAMICROSS] [float](2) NULL,
	[Pattern_CDLHIGHWAVE] [float](2) NULL,
	[Pattern_CDLHIKKAKE] [float](2) NULL,
	[Pattern_CDLHIKKAKEMOD] [float](2) NULL,
	[Pattern_CDLHOMINGPIGEON] [float](2) NULL,
	[Pattern_CDLIDENTICAL3CROWS] [float](2) NULL,
	[Pattern_CDLINNECK] [float](2) NULL,
	[Pattern_CDLINVERTEDHAMMER] [float](2) NULL,
	[Pattern_CDLKICKING] [float](2) NULL,
	[Pattern_CDLKICKINGBYLENGTH] [float](2) NULL,
	[Pattern_CDLLADDERBOTTOM] [float](2) NULL,
	[Pattern_CDLLONGLEGGEDDOJI] [float](2) NULL,
	[Pattern_CDLLONGLINE] [float](2) NULL,
	[Pattern_CDLMARUBOZU] [float](2) NULL,
	[Pattern_CDLMATCHINGLOW] [float](2) NULL,
	[Pattern_CDLMATHOLD] [float](2) NULL,
	[Pattern_CDLMORNINGDOJISTAR] [float](2) NULL,
	[Pattern_CDLMORNINGSTAR] [float](2) NULL,
	[Pattern_CDLONNECK] [float](2) NULL,
	[Pattern_CDLPIERCING] [float](2) NULL,
	[Pattern_CDLRICKSHAWMAN] [float](2) NULL,
	[Pattern_CDLRISEFALL3METHODS] [float](2) NULL,
	[Pattern_CDLSEPARATINGLINES] [float](2) NULL,
	[Pattern_CDLSHOOTINGSTAR] [float](2) NULL,
	[Pattern_CDLSHORTLINE] [float](2) NULL,
	[Pattern_CDLSPINNINGTOP] [float](2) NULL,
	[Pattern_CDLSTALLEDPATTERN] [float](2) NULL,
	[Pattern_CDLSTICKSANDWICH] [float](2) NULL,
	[Pattern_CDLTAKURI] [float](2) NULL,
	[Pattern_CDLTASUKIGAP] [float](2) NULL,
	[Pattern_CDLTHRUSTING] [float](2) NULL,
	[Pattern_CDLTRISTAR] [float](2) NULL,
	[Pattern_CDLUNIQUE3RIVER] [float](2) NULL,
	[Pattern_CDLUPSIDEGAP2CROWS] [float](2) NULL,
	[Pattern_CDLXSIDEGAP3METHODS] [float](2) NULL,
	[Price_AVGPRICE] [float](2) NULL,
	[Price_MEDPRICE] [float](2) NULL,
	[Price_TYPPRICE] [float](2) NULL,
	[Price_WCLPRICE] [float](2) NULL,
	[Statistic_BETA] [float](2) NULL,
	[Statistic_CORREL] [float](2) NULL,
	[Statistic_LINEARREG] [float](2) NULL,
	[Statistic_LINEARREG_ANGLE] [float](2) NULL,
	[Statistic_LINEARREG_INTERCEPT] [float](2) NULL,
	[Statistic_LINEARREG_SLOPE] [float](2) NULL,
	[Statistic_STDDEV] [float](2) NULL,
	[Statistic_TSF] [float](2) NULL,
	[Statistic_VAR] [float](2) NULL,
	[Volatility_ATR] [float](2) NULL,
	[Volatility_NATR] [float](2) NULL,
	[Volatility_TRANGE] [float](2) NULL,
	[Volume_AD] [float](2) NULL,
	[Volume_ADOSC] [float](2) NULL,
	[Volume_OBV] [float](2) NULL,
	[calculation_timestamp] [datetime] default current_timestamp
)
"""

engine = create_engine(f'mssql+pyodbc://{HOST}/{DB}?trusted_connection=yes&driver={DRIVER}')
conn = engine.connect()

def execute_sql(query, commit=False):
    result = conn.execute(text(query))
    if commit:
        conn.commit()
    return result

execute_sql(CREATE_OUTPUT_TABLE_QUERY, commit=True)

def convert_fdataype(df):
    for cname in df.columns:
        if cname in [column_mappings["date"], column_mappings["symbol"], column_mappings["series"],
                     "Math_COSH", "Math_EXP", "Math_SINH"]:
            continue
        try:
            df[cname] = round(df[cname].astype(float), 2)
        except (TypeError, ValueError):
            pass
    return df

def calculate_indicators(df):
    df.rename(columns={column_mappings["open"]:"open", column_mappings["high"]:"high", column_mappings["low"]: "low",
                       column_mappings["volume"]: "volume", column_mappings["close"]: "close"}, inplace=True)
    df_1 = df.copy()
    all_functions = talib.get_functions()
    for indicator in all_functions:
        if indicator in ("ACOS", "ASIN", "MAVP"):
            continue
        name = f'{getattr(abstract, indicator).info["group"].split(" ")[0]}_{getattr(abstract, indicator).info["name"].split(" ")[0]}'
        try:
            output = getattr(abstract, indicator)(df)
        except:
            print(indicator)
        if type(output) == type(df):
            for col_name in output.columns:
                output.rename(columns={col_name: f"{name}_{col_name}"}, inplace=True)
        else:
            output = pd.DataFrame(output, columns=[name])
        df_1 = df_1.join(output)
    return df_1


def main(sym):
    INC_CHECK_QUERY = INCREMENTAL_CHECK_QUERY.format(HISTORY_TABLE_NAME=HISTORY_TABLE, CALC_TABLE_NAME=OUTPUT_TABLENAME,
                                                     SYMBOL_NAME=sym, DATE_COLUMN_NAME=column_mappings["date"],
                                                     SYMBOL_COLUMN_NAME=column_mappings["symbol"])
    inc_df = pd.read_sql_query(INC_CHECK_QUERY, engine)
    if inc_df.empty:
        print(f"No new data to calculate for {sym}..")
        return
    TEMP_DF_QUERY = GET_PREVIOUS_DAYS_QUERY.format(NO_OF_ROWS=90+inc_df.shape[0], SYMBOL_NAME=sym, HISTORY_TABLE_NAME=HISTORY_TABLE,
                                                   SYMBOL_COLUMN_NAME=column_mappings["symbol"], DATE_COLUMN_NAME=column_mappings["date"])
    temp_df = pd.read_sql_query(TEMP_DF_QUERY, engine)
    temp_df = temp_df.sort_values(by=column_mappings["date"])
    print(f"Calculating indicators for {sym}. Total rows to calculate {inc_df.shape[0]}")
    temp_df_na = dropna(temp_df)
    if len(temp_df_na) < 1:
        temp_df_na = temp_df
        
    df_ = calculate_indicators(temp_df_na)
    df_ = convert_fdataype(df_)
    df_.replace([np.inf, -np.inf], np.nan, inplace=True)
#     return df_
    try:
        df_.tail(inc_df.shape[0]).to_sql(OUTPUT_TABLENAME, engine, if_exists="append", index=False, chunksize=30)
        print(f"Updated calculations for {sym} in database")
    except:
        print("Error on calculation {}".format(sym))


def concurrent_request(function, iterable_list, no_of_workers=10, parser_func= None):
    if not hasattr(iterable_list, "__iter__"):
        raise Exception("Please pass iterable object")
    try:
        with concurrent.futures.ThreadPoolExecutor(max_workers=no_of_workers) as executor:
            data = executor.map(function, iterable_list)
    except KeyboardInterrupt as e:
        print(e)
        
#     _ = [i for i in data]
    return True

# %% [markdown]
# ## Run below code to calculate indicators

# %%
symbol_lst = [i.Symbol for i in execute_sql(f'select {column_mappings["symbol"]} from {HISTORY_TABLE} Group by \
                                                {column_mappings["symbol"]}')]

concurrent_request(main, symbol_lst, NO_OF_WORKERS)
# Out:
# Calculating indicators for 0JMFCSL22   . Total rows to calculate 41
# Calculating indicators for 0IFCI25     . Total rows to calculate 6
# Updated calculations for 0IFCI25      in database
# Updated calculations for 0JMFCSL22    in database
# Calculating indicators for 0KFL22F     . Total rows to calculate 11
# Calculating indicators for 0JMFPL26    . Total rows to calculate 26
# Updated calculations for 0KFL22F      in database
# Updated calculations for 0JMFPL26     in database
# Calculating indicators for 0LTFL22C    . Total rows to calculate 6
# Calculating indicators for 0MFCL26VIII . Total rows to calculate 24
# Updated calculations for 0LTFL22C     in database
# Updated calculations for 0MFCL26VIII  in database
# Calculating indicators for 0MFL24      . Total rows to calculate 46
# Updated calculations for 0MFL24       in database
# Calculating indicators for 0MMFL24A    . Total rows to calculate 6
# Calculating indicators for 0NWFL25     . Total rows to calculate 26
# Updated calculations for 0MMFL24A     in database
# Updated calculations for 0NWFL25      in database
# Calculating indicators for 0PFL24B     . Total rows to calculate 3
# Updated calculations for 0PFL24B      in database
# Calculating indicators for 0SEFL27     . Total rows to calculate 1
# Calculating indicators for 0SEFL22B    . Total rows to calculate 5
# Updated calculations for 0SEFL27      in database
# Updated calculations for 0SEFL22B     in database
# Calculating indicators for 1015UPPCL25 . Total rows to calculate 132
# Calculating indicators for 0STFCL23A   . Total rows to calculate 36
# Updated calculations for 0STFCL23A    in database
# Updated calculations for 1015UPPCL25  in database
# Calculating indicators for 1025SFL24B  . Total rows to calculate 23
# Calculating indicators for 101JMFCSL23 . Total rows to calculate 108
# Updated calculations for 1025SFL24B   in database
# Calculating indicators for 1025STFL24  . Total rows to calculate 121
# Updated calculations for 101JMFCSL23  in database
# Updated calculations for 1025STFL24   in database
# Calculating indicators for 1027PFL29   . Total rows to calculate 4
# Calculating indicators for 1032APCRD26 . Total rows to calculate 63
# Updated calculations for 1027PFL29    in database
# Updated calculations for 1032APCRD26  in database
# Calculating indicators for 1041KFL26   . Total rows to calculate 7
# Updated calculations for 1041KFL26    in database
# Calculating indicators for 1049DLSL25  . Total rows to calculate 26
# Updated calculations for 1049DLSL25   in database
# Calculating indicators for 104ECL24    . Total rows to calculate 177
# Calculating indicators for 1050DLSL24  . Total rows to calculate 93
# Updated calculations for 1050DLSL24   in database
# Updated calculations for 104ECL24     in database
# Calculating indicators for 1050UCL26   . Total rows to calculate 3
# Calculating indicators for 1071KFL25   . Total rows to calculate 5
# Updated calculations for 1050UCL26    in database
# Updated calculations for 1071KFL25    in database
# Calculating indicators for 07AGG       . Total rows to calculate 140
# Calculating indicators for 1075PFL29   . Total rows to calculate 3
# Updated calculations for 1075PFL29    in database
# Updated calculations for 07AGG        in database
# Calculating indicators for 0DLSL22     . Total rows to calculate 18
# Calculating indicators for 06ARD       . Total rows to calculate 19
# Updated calculations for 0DLSL22      in database
# Updated calculations for 06ARD        in database
# Calculating indicators for 08ABB       . Total rows to calculate 7
# Calculating indicators for 04AGG       . Total rows to calculate 19
# Updated calculations for 08ABB        in database
# Updated calculations for 04AGG        in database
# Calculating indicators for 0DLSL24     . Total rows to calculate 79
# Calculating indicators for 0DLSL24A    . Total rows to calculate 13
# Updated calculations for 0DLSL24A     in database
# Updated calculations for 0DLSL24      in database
# Calculating indicators for 0IFCI24G    . Total rows to calculate 34
# Calculating indicators for 04GPG       . Total rows to calculate 19
# Updated calculations for 04GPG        in database
# Updated calculations for 0IFCI24G     in database
# Calculating indicators for 07GPG       . Total rows to calculate 297
# Calculating indicators for 06GPG       . Total rows to calculate 19
# Updated calculations for 06GPG        in database
# Updated calculations for 07GPG        in database
# Calculating indicators for 08AMD       . Total rows to calculate 1
# Calculating indicators for 0ECL24      . Total rows to calculate 91
# Updated calculations for 08AMD        in database
# Updated calculations for 0ECL24       in database
# Calculating indicators for 0IFL26      . Total rows to calculate 3
# Calculating indicators for 0001AIPL24  . Total rows to calculate 1
# Updated calculations for 0IFL26       in database
# Updated calculations for 0001AIPL24   in database
# Calculating indicators for 08DPR       . Total rows to calculate 1
# Calculating indicators for 001PSL35    . Total rows to calculate 2
# Updated calculations for 08DPR        in database
# Updated calculations for 001PSL35     in database
# Calculating indicators for 0CCIL25     . Total rows to calculate 1
# Calculating indicators for 0IBHFL26A   . Total rows to calculate 4
# Updated calculations for 0CCIL25      in database
# Updated calculations for 0IBHFL26A    in database
# Calculating indicators for 0IIFL24     . Total rows to calculate 8
# Updated calculations for 0IIFL24      in database
# Calculating indicators for 0KFL23B     . Total rows to calculate 19
# Calculating indicators for 0KFL28      . Total rows to calculate 1
# Updated calculations for 0KFL28       in database
# Updated calculations for 0KFL23B      in database
# Calculating indicators for 0KLMF23     . Total rows to calculate 2
# Updated calculations for 0KLMF23      in database
# Calculating indicators for 0KFLSRV     . Total rows to calculate 7
# Updated calculations for 0KFLSRV      in database
# Calculating indicators for 0KSFL24     . Total rows to calculate 30
# Updated calculations for 0KSFL24      in database
# Calculating indicators for 0MFL23VI    . Total rows to calculate 115
# Calculating indicators for 0MFL24A     . Total rows to calculate 75
# Updated calculations for 0MFL23VI     in database
# Updated calculations for 0MFL24A      in database
# Calculating indicators for 0MFL25B     . Total rows to calculate 48
# Calculating indicators for 0MFL26VIII  . Total rows to calculate 28
# Updated calculations for 0MFL26VIII   in database
# Updated calculations for 0MFL25B      in database
# Calculating indicators for 0MMFL27     . Total rows to calculate 19
# Updated calculations for 0MMFL27      in database
# Calculating indicators for 0MVAFL25    . Total rows to calculate 12
# Calculating indicators for 0SEFL22C    . Total rows to calculate 4
# Updated calculations for 0SEFL22C     in database
# Updated calculations for 0MVAFL25     in database
# Calculating indicators for 0SFL24      . Total rows to calculate 22
# Calculating indicators for 0SFL24A     . Total rows to calculate 2
# Updated calculations for 0SFL24       in database
# Updated calculations for 0SFL24A      in database
# Calculating indicators for 06AGG       . Total rows to calculate 19
# Calculating indicators for  EMERALD    . Total rows to calculate 307
# Updated calculations for 06AGG        in database
# Calculating indicators for 08MPR       . Total rows to calculate 1
# Updated calculations for 08MPR        in database
# Updated calculations for  EMERALD     in database
# Calculating indicators for 09GPG       . Total rows to calculate 288
# Calculating indicators for 0EFL22      . Total rows to calculate 91
# Updated calculations for 09GPG        in database
# Updated calculations for 0EFL22       in database
# Calculating indicators for 0IIFL26     . Total rows to calculate 3
# Calculating indicators for 0EFL23      . Total rows to calculate 79
# Updated calculations for 0IIFL26      in database
# Calculating indicators for 0IIFL28     . Total rows to calculate 2
# Updated calculations for 0IIFL28      in databaseUpdated calculations for 0EFL23       in database
#
# Calculating indicators for 0KAFL23     . Total rows to calculate 1
# Calculating indicators for 0KFL23AA    . Total rows to calculate 13
# Updated calculations for 0KAFL23      in database
# Updated calculations for 0KFL23AA     in database
# Calculating indicators for 0KFL25      . Total rows to calculate 7
# Calculating indicators for 0MFCL23VI   . Total rows to calculate 136
# Updated calculations for 0KFL25       in database
# Updated calculations for 0MFCL23VI    in database
# Calculating indicators for 0MFL23A5    . Total rows to calculate 19
# Calculating indicators for 0MFL23CC    . Total rows to calculate 55
# Updated calculations for 0MFL23A5     in database
# Updated calculations for 0MFL23CC     in database
# Calculating indicators for 0MHFL22     . Total rows to calculate 65
# Calculating indicators for 0MMFL24B    . Total rows to calculate 16
# Updated calculations for 0MMFL24B     in database
# Updated calculations for 0MHFL22      in database
# Calculating indicators for 0MVAFL23    . Total rows to calculate 35
# Calculating indicators for 0MVAFL22    . Total rows to calculate 2
# Updated calculations for 0MVAFL22     in database
# Updated calculations for 0MVAFL23     in database
# Calculating indicators for 0SEFL28     . Total rows to calculate 1
# Updated calculations for 0SEFL28      in database
# Calculating indicators for 1005SEFL22  . Total rows to calculate 19
# Updated calculations for 1005SEFL22   in database
# Calculating indicators for 1010EFSL28  . Total rows to calculate 6
# Updated calculations for 1010EFSL28   in database
# Calculating indicators for 1025KFL23   . Total rows to calculate 2
# Calculating indicators for 1020EFL22   . Total rows to calculate 31
# Updated calculations for 1025KFL23    in database
# Updated calculations for 1020EFL22    in database
# Calculating indicators for 1025KFL26C  . Total rows to calculate 6
# Calculating indicators for 1025MOHFL24 . Total rows to calculate 1
# Updated calculations for 1025MOHFL24  in database
# Updated calculations for 1025KFL26C   in database
# Calculating indicators for 1025STFCL24 . Total rows to calculate 109
# Calculating indicators for 1032APCRD28 . Total rows to calculate 14
# Updated calculations for 1032APCRD28  in database
# Updated calculations for 1025STFCL24  in database
# Calculating indicators for 1035MMFL24  . Total rows to calculate 3
# Calculating indicators for 1040MCSL24  . Total rows to calculate 1
# Updated calculations for 1035MMFL24   in database
# Updated calculations for 1040MCSL24   in database
# Calculating indicators for 104ECL29    . Total rows to calculate 100
# Calculating indicators for 104EFL24    . Total rows to calculate 188
# Updated calculations for 104ECL29     in database
# Updated calculations for 104EFL24     in database
# Calculating indicators for 1050HFL28   . Total rows to calculate 6
# Calculating indicators for 1050CCIL24  . Total rows to calculate 43
# Updated calculations for 1050HFL28    in database
# Updated calculations for 1050CCIL24   in database
# Calculating indicators for 1050IML23   . Total rows to calculate 32
# Calculating indicators for 1050SFL26   . Total rows to calculate 22
# Updated calculations for 1050SFL26    in database
# Updated calculations for 1050IML23    in database
# Calculating indicators for 1095SMPL24  . Total rows to calculate 10
# Calculating indicators for 10AGG       . Total rows to calculate 45
# Updated calculations for 1095SMPL24   in database
# Calculating indicators for 10CIFCLPERP . Total rows to calculate 3
# Updated calculations for 10AGG        in database
# Updated calculations for 10CIFCLPERP  in database
# Calculating indicators for 10KFL24A    . Total rows to calculate 1
# Calculating indicators for 10MMFL23    . Total rows to calculate 7
# Updated calculations for 10KFL24A     in database
# Updated calculations for 10MMFL23     in database
# Calculating indicators for 10MMFL23B   . Total rows to calculate 6
# Updated calculations for 10MMFL23B    in database
# Calculating indicators for 10SFL23     . Total rows to calculate 2
# Updated calculations for 10SFL23      in database
# Calculating indicators for 10STFC2024  . Total rows to calculate 4
# Calculating indicators for 1125LFL23   . Total rows to calculate 1
# Updated calculations for 10STFC2024   in database
# Updated calculations for 1125LFL23    in database
# Calculating indicators for 653TNSDL31  . Total rows to calculate 4
# Updated calculations for 653TNSDL31   in database
# Calculating indicators for 12KAFL23    . Total rows to calculate 37
# Calculating indicators for 676GOI2061  . Total rows to calculate 34
# Updated calculations for 676GOI2061   in database
# Updated calculations for 12KAFL23     in database
# Calculating indicators for 682JNPT2023 . Total rows to calculate 7
# Updated calculations for 682JNPT2023  in database
# Calculating indicators for 702APSDL37  . Total rows to calculate 2
# Calculating indicators for 709REC30    . Total rows to calculate 2
# Updated calculations for 702APSDL37   in database
# Updated calculations for 709REC30     in database
# Calculating indicators for 711NTPC25A  . Total rows to calculate 10
# Calculating indicators for 719IRFC2022 . Total rows to calculate 1
# Updated calculations for 719IRFC2022  in database
# Updated calculations for 711NTPC25A   in database
# Calculating indicators for 727GOI2026  . Total rows to calculate 1
# Calculating indicators for 724MHSDL29  . Total rows to calculate 7
# Updated calculations for 727GOI2026   in database
# Updated calculations for 724MHSDL29   in database
# Calculating indicators for 735NHAI31   . Total rows to calculate 74
# Calculating indicators for 736NTPC25D  . Total rows to calculate 88
# Updated calculations for 735NHAI31    in database
# Updated calculations for 736NTPC25D   in database
# Calculating indicators for 749IREDA31  . Total rows to calculate 26
# Updated calculations for 749IREDA31   in database
# Calculating indicators for 750IRFC35   . Total rows to calculate 63
# Updated calculations for 750IRFC35    in database
# Calculating indicators for 753NTPC30E  . Total rows to calculate 16
# Updated calculations for 753NTPC30E   in database
# Calculating indicators for 754GOI2036  . Total rows to calculate 66
# Calculating indicators for 754NABARD32 . Total rows to calculate 1
# Updated calculations for 754NABARD32  in database
# Updated calculations for 754GOI2036   in database
# Calculating indicators for 760MFL25    . Total rows to calculate 16
# Calculating indicators for 764IRFC31   . Total rows to calculate 146
# Updated calculations for 760MFL25     in database
# Updated calculations for 764IRFC31    in database
# Calculating indicators for 769KSDL27   . Total rows to calculate 1
# Calculating indicators for 76MHSDL30   . Total rows to calculate 7
# Updated calculations for 769KSDL27    in database
# Updated calculations for 76MHSDL30    in database
# Calculating indicators for 76NHAI31    . Total rows to calculate 256
# Calculating indicators for 774IREDA31  . Total rows to calculate 121
# Updated calculations for 774IREDA31   in database
# Updated calculations for 76NHAI31     in database
# Calculating indicators for 775SBIPER   . Total rows to calculate 1
# Calculating indicators for 775GUJSDL32 . Total rows to calculate 2
# Updated calculations for 775SBIPER    in database
# Updated calculations for 775GUJSDL32  in database
# Calculating indicators for 797HDFCL33  . Total rows to calculate 16
# Updated calculations for 797HDFCL33   in database
# Calculating indicators for 798BHFL27   . Total rows to calculate 1
# Updated calculations for 798BHFL27    in database
# Calculating indicators for 7NR         . Total rows to calculate 283
# Calculating indicators for 805GUJ2028  . Total rows to calculate 2
# Updated calculations for 805GUJ2028   in database
# Calculating indicators for 808MHSDL28  . Total rows to calculate 1
# Updated calculations for 808MHSDL28   in database
# Updated calculations for 7NR          in database
# Calculating indicators for 0EFSL26     . Total rows to calculate 55
# Calculating indicators for 08MPD       . Total rows to calculate 307
# Updated calculations for 0EFSL26      in database
# Updated calculations for 08MPD        in database
# Calculating indicators for 0EFSL26B    . Total rows to calculate 60
# Calculating indicators for 0IFL22A     . Total rows to calculate 24
# Updated calculations for 0IFL22A      in database
# Updated calculations for 0EFSL26B     in database
# Calculating indicators for 0IFL28      . Total rows to calculate 38
# Calculating indicators for 0KFL22E     . Total rows to calculate 6
# Updated calculations for 0KFL22E      in database
# Updated calculations for 0IFL28       in database
# Calculating indicators for 0KFL26A     . Total rows to calculate 9
# Updated calculations for 0KFL26A      in database
# Calculating indicators for 0KFL23A     . Total rows to calculate 19
# Calculating indicators for 0KFL28A     . Total rows to calculate 13
# Updated calculations for 0KFL23A      in databaseUpdated calculations for 0KFL28A      in database
#
# Calculating indicators for 0MFCL24VII  . Total rows to calculate 30
# Calculating indicators for 0KLML23     . Total rows to calculate 13
# Updated calculations for 0KLML23      in database
# Updated calculations for 0MFCL24VII   in database
# Calculating indicators for 0MFL23C     . Total rows to calculate 116
# Calculating indicators for 0MFL25C     . Total rows to calculate 45
# Updated calculations for 0MFL23C      in database
# Updated calculations for 0MFL25C      in database
# Calculating indicators for 0MMFL28     . Total rows to calculate 3
# Calculating indicators for 0MMFL27A    . Total rows to calculate 14
# Updated calculations for 0MMFL27A     in database
# Updated calculations for 0MMFL28      in database
# Calculating indicators for 0SCUF22A    . Total rows to calculate 19
# Calculating indicators for 0SCUF24A    . Total rows to calculate 12
# Updated calculations for 0SCUF24A     in database
# Updated calculations for 0SCUF22A     in database
# Calculating indicators for 1003UCL24   . Total rows to calculate 151
# Calculating indicators for 0SFL23AB    . Total rows to calculate 1
# Updated calculations for 0SFL23AB     in database
# Updated calculations for 1003UCL24    in database
# Calculating indicators for 1004DLSL24  . Total rows to calculate 3
# Calculating indicators for 1015UCL24A  . Total rows to calculate 35
# Updated calculations for 1004DLSL24   in database
# Updated calculations for 1015UCL24A   in database
# Calculating indicators for 1025SFL25   . Total rows to calculate 8
# Updated calculations for 1025SFL25    in database
# Calculating indicators for 102HDB2023B . Total rows to calculate 1
# Updated calculations for 102HDB2023B  in database
# Calculating indicators for 102JMFPL22  . Total rows to calculate 25
# Updated calculations for 102JMFPL22   in database
# Calculating indicators for 1049DLSL22  . Total rows to calculate 20
# Calculating indicators for 1032APCRD24 . Total rows to calculate 6
# Updated calculations for 1049DLSL22   in database
# Updated calculations for 1032APCRD24  in database
# Calculating indicators for 1061DLSL24  . Total rows to calculate 18
# Calculating indicators for 105MMFL25C  . Total rows to calculate 41
# Updated calculations for 1061DLSL24   in database
# Updated calculations for 105MMFL25C   in database
# Calculating indicators for 1065MHFL24  . Total rows to calculate 27
# Updated calculations for 1065MHFL24   in database
# Calculating indicators for 10BUDPL26   . Total rows to calculate 3
# Calculating indicators for 10MFL22     . Total rows to calculate 13
# Updated calculations for 10BUDPL26    in database
# Updated calculations for 10MFL22      in database
# Calculating indicators for 1164MECL29  . Total rows to calculate 2
# Calculating indicators for 10MFL24     . Total rows to calculate 148
# Updated calculations for 1164MECL29   in database
# Updated calculations for 10MFL24      in database
# Calculating indicators for 11GPG       . Total rows to calculate 307
# Calculating indicators for 11MML26     . Total rows to calculate 38
# Updated calculations for 11MML26      in database
# Updated calculations for 11GPG        in database
# Calculating indicators for 129SMP26    . Total rows to calculate 1
# Updated calculations for 129SMP26     in database
# Calculating indicators for 1375SIBLPER . Total rows to calculate 133
# Calculating indicators for 1646ILFS22B . Total rows to calculate 1
# Updated calculations for 1646ILFS22B  in database
# Updated calculations for 1375SIBLPER  in database
# Calculating indicators for 633TNSDL30  . Total rows to calculate 4
# Calculating indicators for 619GOI2034  . Total rows to calculate 1
# Updated calculations for 633TNSDL30   in database
# Updated calculations for 619GOI2034   in database
# Calculating indicators for 63MOONS     . Total rows to calculate 307Calculating indicators for 702IIFCL28  . Total rows to calculate 2
#
# Updated calculations for 702IIFCL28   in database
# Updated calculations for 63MOONS      in database
# Calculating indicators for 714NHAI26   . Total rows to calculate 5
# Calculating indicators for 714APSDL36  . Total rows to calculate 3
# Updated calculations for 714NHAI26    in database
# Updated calculations for 714APSDL36   in database
# Calculating indicators for 715NTPC25   . Total rows to calculate 3
# Calculating indicators for 719IIFCL23  . Total rows to calculate 52
# Updated calculations for 715NTPC25    in database
# Updated calculations for 719IIFCL23   in database
# Calculating indicators for 732GOI2024  . Total rows to calculate 1
# Calculating indicators for 728IREDA26  . Total rows to calculate 1
# Updated calculations for 732GOI2024   in database
# Updated calculations for 728IREDA26   in database
# Calculating indicators for 07ABB       . Total rows to calculate 2
# Calculating indicators for 08DPD       . Total rows to calculate 2
# Updated calculations for 07ABB        in database
# Updated calculations for 08DPD        in database
# Calculating indicators for 08QPR       . Total rows to calculate 1
# Updated calculations for 08QPR        in database
# Calculating indicators for 0STFCL24    . Total rows to calculate 71
# Calculating indicators for 0EFSL24A    . Total rows to calculate 68
# Updated calculations for 0EFSL24A     in database
# Updated calculations for 0STFCL24     in database
# Calculating indicators for 1003DLSL22  . Total rows to calculate 8
# Calculating indicators for 1003DLSL24  . Total rows to calculate 18
# Updated calculations for 1003DLSL22   in database
# Updated calculations for 1003DLSL24   in database
# Calculating indicators for 1015HLFL25  . Total rows to calculate 2
# Updated calculations for 1015HLFL25   in database
# Calculating indicators for 1015UCL24   . Total rows to calculate 10
# Calculating indicators for 1015UPPCL26 . Total rows to calculate 105
# Updated calculations for 1015UCL24    in database
# Updated calculations for 1015UPPCL26  in database
# Calculating indicators for 1015UPPCL27 . Total rows to calculate 77
# Calculating indicators for 1025SFL24   . Total rows to calculate 1
# Updated calculations for 1025SFL24    in database
# Calculating indicators for 102ECL23    . Total rows to calculate 168
# Updated calculations for 1015UPPCL27  in database
# Updated calculations for 102ECL23     in database
# Calculating indicators for 102EFL22    . Total rows to calculate 84
# Calculating indicators for 1040DLSL22  . Total rows to calculate 21
# Updated calculations for 1040DLSL22   in database
# Updated calculations for 102EFL22     in database
# Calculating indicators for 1050KLMA28  . Total rows to calculate 1
# Calculating indicators for 1050HFL27   . Total rows to calculate 11
# Updated calculations for 1050KLMA28   in database
# Updated calculations for 1050HFL27    in database
# Calculating indicators for 1050SEFL22  . Total rows to calculate 48
# Calculating indicators for 105AML23    . Total rows to calculate 5
# Updated calculations for 105AML23     in database
# Updated calculations for 1050SEFL22   in database
# Calculating indicators for 1095KFI22   . Total rows to calculate 2
# Calculating indicators for 1075SEFL24  . Total rows to calculate 52
# Updated calculations for 1095KFI22    in database
# Updated calculations for 1075SEFL24   in database
# Calculating indicators for 10ARD       . Total rows to calculate 301
# Calculating indicators for 10BUDPL26A  . Total rows to calculate 2
# Updated calculations for 10BUDPL26A   in database
# Updated calculations for 10ARD        in database
# Calculating indicators for 10BUDPL26B  . Total rows to calculate 2
# Updated calculations for 10BUDPL26B   in database
# Calculating indicators for 10IFL25     . Total rows to calculate 89
# Calculating indicators for 10IHFL28    . Total rows to calculate 122
# Updated calculations for 10IFL25      in database
# Updated calculations for 10IHFL28     in database
# Calculating indicators for 10MMFL24    . Total rows to calculate 4
# Updated calculations for 10MMFL24     in database
# Calculating indicators for 10SFL25     . Total rows to calculate 7
# Calculating indicators for 10KFIL27    . Total rows to calculate 72
# Updated calculations for 10SFL25      in database
# Calculating indicators for 115PFLPER   . Total rows to calculate 2
# Updated calculations for 115PFLPER    in database
# Updated calculations for 10KFIL27     in database
# Calculating indicators for 11DLSL24    . Total rows to calculate 66
# Calculating indicators for 1318BFL24   . Total rows to calculate 2
# Updated calculations for 1318BFL24    in database
# Updated calculations for 11DLSL24     in database
# Calculating indicators for 15EPDPL30   . Total rows to calculate 1
# Updated calculations for 15EPDPL30    in database
# Calculating indicators for 48PFCL24    . Total rows to calculate 37
# Calculating indicators for 653KARSDL30 . Total rows to calculate 1
# Updated calculations for 653KARSDL30  in database
# Updated calculations for 48PFCL24     in database
# Calculating indicators for 695TNSDL31  . Total rows to calculate 2
# Calculating indicators for 663KARSDL34 . Total rows to calculate 1
# Updated calculations for 695TNSDL31   in database
# Updated calculations for 663KARSDL34  in database
# Calculating indicators for 698APSDL36  . Total rows to calculate 2
# Calculating indicators for 701MHSDL32  . Total rows to calculate 6
# Updated calculations for 698APSDL36   in database
# Updated calculations for 701MHSDL32   in database
# Calculating indicators for 702HUDCO26  . Total rows to calculate 3
# Updated calculations for 702HUDCO26   in database
# Calculating indicators for 815LTFL22   . Total rows to calculate 19
# Calculating indicators for 816IIFCL24  . Total rows to calculate 1
# Updated calculations for 816IIFCL24   in database
# Updated calculations for 815LTFL22    in database
# Calculating indicators for 825MFL23A   . Total rows to calculate 126
# Calculating indicators for 825MFL25A   . Total rows to calculate 19
# Updated calculations for 825MFL25A    in database
# Updated calculations for 825MFL23A    in database
# Calculating indicators for 838IIFCL28  . Total rows to calculate 4
# Calculating indicators for 839HUDCO23  . Total rows to calculate 184
# Updated calculations for 838IIFCL28   in database
# Calculating indicators for 841IREDA24  . Total rows to calculate 23
# Updated calculations for 841IREDA24   in database
# Updated calculations for 839HUDCO23   in database
# Calculating indicators for 842IHFL24   . Total rows to calculate 6
# Updated calculations for 842IHFL24    in database
# Calculating indicators for 844IRFC24   . Total rows to calculate 22
# Calculating indicators for 846PFC28    . Total rows to calculate 7
# Updated calculations for 844IRFC24    in database
# Updated calculations for 846PFC28     in database
# Calculating indicators for 850MFL27    . Total rows to calculate 44
# Calculating indicators for 850SBIPER   . Total rows to calculate 47
# Updated calculations for 850MFL27     in database
# Updated calculations for 850SBIPER    in database
# Calculating indicators for 855IREDA29  . Total rows to calculate 3
# Calculating indicators for 850STFCL26  . Total rows to calculate 4
# Updated calculations for 850STFCL26   in database
# Updated calculations for 855IREDA29   in database
# Calculating indicators for 10BUDPL26C  . Total rows to calculate 6
# Calculating indicators for 1075SEFL29  . Total rows to calculate 6
# Updated calculations for 10BUDPL26C   in database
# Updated calculations for 1075SEFL29   in database
